# %%
import spacy
from spacy.tokens import DocBin
import ast
import os

# %%
import pandas as pd
import spacy
from spacy.tokens import DocBin
from spacy.training import Example

# Charger les données
train_df = pd.read_csv('train_2.csv')
test_df = pd.read_csv('test.csv')

def prepare_data(df):
    db = DocBin()  # Pour stocker les documents
    nlp = spacy.blank("en")  # Créer un modèle vide

    for _, row in df.iterrows():
        doc = nlp.make_doc(row['sentence'])
        ents = []
        covered_chars = set()  # Ensemble pour suivre les caractères déjà couverts

        for word, label in zip(eval(row['words']), eval(row['labels'])):
            if label in ['person', 'content']:
                start = row['sentence'].find(word)
                end = start + len(word)

                # Vérifier si le span actuel chevauche un span précédemment ajouté
                if not any((start <= c < end) for c in covered_chars):
                    span = doc.char_span(start, end, label=label)
                    if span is not None:
                        ents.append(span)
                        covered_chars.update(range(start, end))  # Marquer les caractères comme couverts

        doc.ents = ents
        db.add(doc)
    return db


# Préparer les données d'entraînement et de test
train_data = prepare_data(train_df)
test_data = prepare_data(test_df)

# Enregistrer les données préparées
train_data.to_disk("train.spacy")
test_data.to_disk("test.spacy")

# Configuration pour l'entraînement
config = spacy.util.load_config("config.cfg")

# Entraîner le modèle
# !spacy train config.cfg --output ./output --paths.train train.spacy --paths.dev test.spacy

print("finished")
# Out:
# ^C
# finished

# %%
def format_api_call(text, nlp_model):
    # Process the text with the trained model
    doc = nlp_model(text)
    
    # Extract entities for "person" and "content"
    receiver = []
    content = []
    for ent in doc.ents:
        if ent.label_ == "person":
            receiver.append(ent.text)
        elif ent.label_ == "content":
            content.append(ent.text)
    
    # Format the API call JSON
    api_call = {
        "job": "send_message",
        "receiver": " ".join(receiver),
        "content": " ".join(content)
    }
    return api_call

# Example usage:
nlp_model = spacy.load("./output/model-best")  # Load your trained model
sentence = "Ask the python teacher when is the next class?"
api_call_json = format_api_call(sentence, nlp_model)
print(api_call_json)
# Out:
# {'job': 'send_message', 'receiver': 'the python teacher', 'content': 'when is next class'}

# %%
from spacy.tokens import DocBin
nlp_trained = spacy.load("./output/model-best")  # Load your trained model

# Load the test data
test_db = DocBin().from_disk("./test.spacy")
test_docs = list(test_db.get_docs(nlp_trained.vocab))

# Example: Process each document in the test set and print the entities
for doc in test_docs:
    print(f"Text: {doc.text}")
    for ent in doc.ents:
        print(f"  {ent.text} ({ent.label_})")
    print("---")
# Out:
# Text: Create a 6 pm note in Notas.
# ---
# Text: Can you create a 8pm note?
# ---
# Text: Can you create a household note for María?
#   María (person)
# ---
# Text: Crea a note for Bob.
#   Bob (person)
# ---
# Text: Nota con reminder crear.
# ---
# Text: Create a memo saying Mitbringbuffet am Mittwoch.
#   Mitbringbuffet (content)
#   am (content)
#   Mittwoch (content)
# ---
# Text: Make a note for Mama on my iPhone.
#   Mama (person)
# ---
# Text: I need make a reminder to get kid son aus dem Kindergarten.
#   get (content)
#   kid (content)
#   son (content)
#   aus (content)
#   dem (content)
#   Kindergarten (content)
# ---
# Text: Take a note for the oficina group, please.
# ---
# Text: Can you create a memo with a Erinnerung?
# ---
# Text: Nota buy milk and eggs crear.
#   buy (content)
#   milk (content)
#   and (content)
#   eggs (content)
# ---
# Text: Por favor, create a note for me.
# ---
# Text: Schreib ein Memo Love and other drugs.
#   Love (content)
#   and (content)
#   other (content)
#   drugs (content)
# ---
# Text: Make a note for François on my Google Home.
#   François (person)
# ---
# Text: New memo dans Google Tasks.
# ---
# Text: Crea a shopping note in Keep.
# ---
# Text: Could you create a memo in my phone saying reunión 12:30.
#   reunión (content)
#   12:30 (content)
# ---
# Text: Create a note for Hélène Gérard.
#   Hélène (person)
#   Gérard (person)
# ---
# Text: Create a Reise Notiz in notes.
# ---
# Text: Let's make a note called पढ़ाई.
# ---
# Text: Create a note for mamá.
#   mamá (person)
# ---
# Text: Crea una note para Roberto.
#   Roberto (person)
# ---
# Text: Start a new note for 太郎 on my desktop.
#   太郎 (person)
# ---
# Text: Can you prepare a memo note called recuerdos to all.
# ---
# Text: Create a compras note in Google Keep for Anna.
#   Anna (person)
# ---
# Text: Create a sticky note for la famille.
# ---
# Text: Create a Erinnerung to buy milk and eggs.
#   buy (content)
#   milk (content)
#   and (content)
#   eggs (content)
# ---
# Text: Let's make a famille memo called chores.
# ---
# Text: Can you create a household note for 私?
#   私 (person)
# ---
# Text: Create a new note with un recordatorio.
# ---
# Text: Make a note for パパ on my iPad.
#   パパ (person)
# ---
# Text: Create a memo to buy chocolate.
#   buy (content)
#   chocolate (content)
# ---
# Text: लिखो a shared memo with a reminder.
# ---
# Text: Create a shopping note in Notas.
# ---
# Text: Crear note for 6 pm.
# ---
# Text: Add this Apple Notes में.
# ---
# Text: Make a Notiz for 9pm.
# ---
# Text: Add this to Google Notizen.
# ---
# Text: Create a memo to book the flight to Bordeaux.
#   to (content)
#   book (content)
#   the (content)
#   flight (content)
#   Bordeaux (content)
# ---
# Text: Let's make a 家族用の memo called chores.
# ---
# Text: Me gustaría crear a shared note with a reminder in Keep for 9pm.
# ---
# Text: Crea una note con un recordatorio.
# ---
# Text: लिखो a household memo.
# ---
# Text: Create a नया note for Bunny.
#   Bunny (person)
# ---
# Text: Let's make a Familien memo called chores.
# ---
# Text: Add this to my notas de Keep.
# ---
# Text: New nota.
# ---
# Text: Make a memo for my Vater.
#   my (person)
#   Vater (person)
# ---
# Text: Can you create a household note for papá?
#   papá (person)
# ---
# Text: Make a memo for 夜9時.
# ---
# Text: Realiza una nota in Keep for 11:00 h.
# ---
# Text: Create a memo saying Hafermilch kaufen.
#   Hafermilch (content)
#   kaufen (content)
# ---
# Text: Write a household memo saying Abendessen.
#   Abendessen (content)
# ---
# Text: Create a sticky note called Je t'aime.
# ---
# Text: Crea a 6pm note.
# ---
# Text: Write a household memo saying fiesta esta noche.
#   fiesta (content)
#   noche (content)
# ---
# Text: I want to create a family to-do nota in Keep.
# ---
# Text: Can you create a 7am Notiz?
# ---
# Text: Add this to Google Keep notes.
# ---
# Text: Create a new メモ with a reminder.
# ---
# Text: Crear a sticky note saying love you.
#   love (content)
#   you (content)
# ---
# Text: Crea una shopping note en Keep.
# ---
# Text: Añade unha nota for María on my iPad.
#   María (person)
# ---
# Text: Make nota for Dad on my iPad.
#   Dad (person)
# ---
# Text: Make a note for भाई on my Galaxy.
#   भाई (person)
# ---
# Text: Make a note for Papa on meinem iPad.
#   Papa (person)
# ---
# Text: बनाओ a shared memo with a remainder.
# ---
# Text: sticky note create करो।
# ---
# Text: Add sortir les poubelles to Google Keep.
#   sortir (content)
#   les (content)
#   poubelles (content)
# ---
# Text: buy milk and eggs का memo create करो।
#   buy (content)
#   milk (content)
#   and (content)
#   eggs (content)
# ---
# Text: Create a 7 Uhr Notiz.
# ---
# Text: Will you create a note Bob के लिए?
#   Bob (person)
# ---
# Text: Erstelle a memo with Google Keep with a Reminder.
# ---
# Text: Make a note for mamá.
#   mamá (person)
# ---
# Text: Create a Erledigungen note in Keep.
# ---
# Text: Add the Google Keep note Ambitionen to my Samsung fone.
# ---
# Text: Could we make a new household memo saying barbecue at Marie-Cécile's on Sunday?
#   barbecue (content)
#   at (content)
#   Marie-Cécile's (content)
#   on (content)
#   Sunday (content)
# ---
# Text: I want to make a note for the famille.
# ---
# Text: Can you create a Familien Notiz for Hildegard?
#   Hildegard (person)
# ---
# Text: Erstelle a memo with Google Keep called shopping list.
# ---
# Text: What Julien Leclerc said in his Skype message?
#   Julien (person)
#   Leclerc (person)
# ---
# Text: Could you give me messages for इस हफ्ते?
# ---
# Text: Could you give me messages for diese Woche?
# ---
# Text: Read me the message from Nathalie Bonnet regarding the village fête.
#   the (content)
#   Nathalie (person)
#   Bonnet (person)
#   village (content)
#   fête (content)
# ---
# Text: Can you give me Textnachrichten with PDF attached in Gmail?
# ---
# Text: I'd like to see the text messages Olivier sent me yesterday.
#   Olivier (person)
# ---
# Text: Mostrar the email with the shopping list.
#   the (content)
#   shopping (content)
#   list (content)
# ---
# Text: I want to see the Textnachricht Bob sent me today.
#   Bob (person)
# ---
# Text: Can you read me Bobs Sprach- nachricht?
#   Bobs (person)
# ---
# Text: Lis me the first 3 messages de Bob.
#   Bob (person)
# ---
# Text: Read me message Amita का about his family emergency के बारे में.
#   Amita (person)
#   his (content)
#   family (content)
#   emergency (content)
# ---
# Text: Display Nachrichten about the last meeting.
# ---
# Text: Unread attachments वाले emails retrieve करो।
# ---
# Text: Get Audio Messages.
# ---
# Text: Could you give me messages for esta semana?
# ---
# Text: Display messages from Juan about the dinner.
#   Juan (person)
# ---
# Text: Can you show me what Pierre said in his courriel ?
#   Pierre (person)
# ---
# Text: Get नया messages.
# ---
# Text: Zeig mir today's messages from Mike.
#   Mike (person)
# ---
# Text: Show me unread messages with pièces jointes.
# ---
# Text: Lee en voz alta my audio messages.
# ---
# Text: Outlook पर pictures attached emails show करो।
# ---
# Text: Get message content from Ana.
# ---
# Text: Quiero ver los starred e-mails on Gmail.
# ---
# Text: Outlook में starred emails show करो।
# ---
# Text: What did ケント say in his email?
#   ケント (person)
# ---
# Text: Affiche le contenu du mail.
# ---
# Text: Get me the Message with the content please rsvp below.
#   please (content)
#   rsvp (content)
#   below (content)
# ---
# Text: Get me the संदेश with the content please handle with care.
#   with (content)
#   please (content)
#   handle (content)
#   care (content)
# ---
# Text: Tell me, was Tom in seiner Message will!
#   Tom (person)
# ---
# Text: Léeme what Ángela said in his message.
#   Ángela (person)
# ---
# Text: I'd like you to show me what's in the message from Jean.
#   Jean (person)
# ---
# Text: Can you display markierte Telegramm Texte today?
# ---
# Text: Qué dice WhatsApp message from Bob?
#   Bob (person)
# ---
# Text: Lies mir die Messages regarding the Party vor!
# ---
# Text: Get the audio messages from mamá móvil.
#   mamá (person)
# ---
# Text: Show me　the message from 金田不動産.
#   金田不動産 (person)
# ---
# Text: Read this courriel for me.
# ---
# Text: Get new messages from dueña de la inmobiliaria on Gmail.
#   dueña (person)
#   de (person)
#   la (person)
#   inmobiliaria (person)
# ---
# Text: I want to see the video message Justine Lemoine just sent to me.
#   Justine (person)
#   Lemoine (person)
# ---
# Text: Get the mensajes de audio.
# ---
# Text: I want to देखना the email Bobby sent me this week.
#   Bobby (person)
# ---
# Text: Let me hear the audio message from Grégoire.
#   Grégoire (person)
# ---
# Text: Can I see my favourite messages on WhatsApp?
# ---
# Text: Lee este email.
# ---
# Text: Could you get my first 3 unread courriels from Gmail ?
# ---
# Text: Could you give me messages for 先週?
# ---
# Text: Get new messages in Skype Empresarial.
# ---
# Text: Display messages about yoga classes.
# ---
# Text: Read the SMS Léonie sent to me yesterday.
#   Léonie (person)
# ---
# Text: Mostrar messages.
# ---
# Text: Show the ungelesenen messages on WhatsApp.
# ---
# Text: Get the Inhalt from the new  message.
# ---
# Text: Read me the message from John Smith regarding su familia.
#   John (person)
#   Smith (person)
#   su (content)
#   familia (content)
# ---
# Text: New Messages regarding the Party vorlesen!
# ---
# Text: Leer first 3 messages from Pedro.
#   Pedro (person)
# ---
# Text: Show me the texto from Antoine.
#   Antoine (person)
# ---
# Text: Play meine Audio Messages!
# ---
# Text: Read the message from papá saying ven ya a casa.
#   papá (person)
#   ven (content)
#   ya (content)
#   casa (content)
# ---
# Text: Quiero ver the text message Pedro sent me today.
#   Pedro (person)
# ---
# Text: I want to see the text Anne sent me yesterday.
#   Anne (person)
# ---
# Text: I want to देखना the text message Bob sent me आज.
#   Bob (person)
# ---
# Text: Peux-tu read the messages from John regarding the project ?
#   John (person)
#   project (content)
# ---
# Text: Get new mensajes.
# ---
# Text: Can you show me unread emails contenant des photos ?
# ---
# Text: I want to see the SMS from Mélanie about the anniversaire de Pierre.
#   Mélanie (person)
#   anniversaire (content)
#   de (content)
#   Pierre (content)
# ---
# Text: I want to check the text message from tante Léa.
#   tante (person)
#   Léa (person)
# ---
# Text: Get messages from 昨日.
# ---
# Text: Can you get me the video message from september 19th about meeting at the café ?
#   the (content)
#   meeting (content)
#   at (content)
#   café (content)
# ---
# Text: Get my audio messages from Émilie on WhatsApp.
#   Émilie (person)
# ---
# Text: Show me the emails I have received about the village fête.
# ---
# Text: Audio Messages rsvp please!
# ---
# Text: Get message 内容.
# ---
# Text: Show me the テキスト from my office about Mr. Anderson's opinion.
#   my (person)
#   office (person)
#   Anderson's (content)
#   opinion (content)
# ---
# Text: Retrieve ungelesene emails with attachments.
# ---
# Text: Could you give me messages for 今週?
# ---
# Text: Can you tell me Bina का message?
#   Bina (person)
# ---
# Text: Could you read Olivier Durand 's message?
#   Olivier (person)
#   Durand (person)
# ---
# Text: I want to see the text message María sent me today.
#   María (person)
# ---
# Text: Mostrar messages about the party tonight.
# ---
# Text: Tell me what the message says from Willie, I mean Simon.
#   Simon (person)
# ---
# Text: Read this Facebook message sorry Twitter message
# ---
# Text: What does the new Facebook message from Danny, actually Susie say?
#   Susie (person)
# ---
# Text: Show me the texts about the party I mean about the fantasy draft.
# ---
# Text: Get me my last five, no, three voice messages.
# ---
# Text: Show me, actually, tell me new messages.
# ---
# Text: Tell me what my new email, I mean message says.
# ---
# Text: Read my audio I mean my video messages in WhatsApp.
# ---
# Text: Read my audio message from yesterday, I mean today.
# ---
# Text: Show me my messages from today, actually yesterday.
# ---
# Text: Tell me what Alexa, I mean Andres said in his Facebook message.
#   Andres (person)
# ---
# Text: Show me, I mean read me the message from Chris.
#   Chris (person)
# ---
# Text: I want to see my messages from Harry from today, no actually from yesterday.
#   Harry (person)
# ---
# Text: Can you read this text no I mean this email?
# ---
# Text: Can you let me know what the message of the day was for Tuesday, I mean Wednesday?
# ---
# Text: Read me my Facebook message from Darrin, oops I mean Darrick.
#   Darrick (person)
# ---
# Text: Please show me my texts er emails from yesterday.
# ---
# Text: What did Christian say in his Facebook, I mean Instagram message?
#   Christian (person)
# ---
# Text: Pull up my read, I mean unread emails on Outlook.
# ---
# Text: Get my video messages from Duo, no Signal.
# ---
# Text: Tell me actually show me new messages with the content please rsvp below.
#   please (content)
#   rsvp (content)
#   below (content)
# ---
# Text: Tell me actually show me unread messages.
# ---
# Text: What's in the message, no, text from Joseph?
#   Joseph (person)
# ---
# Text: Get new audio, I mean video messages.
# ---
# Text: I would like to know what my Facebook I mean Instagram DM says.
# ---
# Text: Get me my last five, no, three text messages.
# ---
# Text: Read me the email from mom, no, dad regarding the wedding event.
#   dad (person)
# ---
# Text: Display the starred emails I mean unread emails.
# ---
# Text: What was in the text message I just received, no actually the one before that?
# ---
# Text: What is the message from Pat no I mean Matt.
#   Matt (person)
# ---
# Text: Read me the email from John with the message, sorry, I mean with the attachment.
#   John (person)
# ---
# Text: Display texts, actually emails in Outlook.
# ---
# Text: Show unread messages from Gmail, no I mean Outlook.
# ---
# Text: Read the WhatsApp message from Jack, uh, I mean John.
#   John (person)
# ---
# Text: Hey can you show me all my missed messages from this morning, sorry, since my lunch break?
# ---
# Text: Get me the message from the read, no, recent label.
# ---
# Text: Get me the email, uh I mean, the message with the content RSVP below.
#   RSVP (content)
#   below (content)
# ---
# Text: Show me my messages from Tuesday, I mean Sunday.
# ---
# Text: Read my Facebook, I mean Instagram message from Stevie.
#   Stevie (person)
# ---
# Text: Tell me the audio iMessage from Wade, I mean my mom.
#   my (person)
#   mom (person)
# ---
# Text: I would like the written, no, video message.
# ---
# Text: What does the text message, no, the email from Joey say?
#   Joey (person)
# ---
# Text: Find starred emails, no, find unread emails.
# ---
# Text: Get video messages, No, voice messages.
# ---
# Text: Read me messages with attachments, sorry, without attachments.
# ---
# Text: Tell me, actually, show me new messages.
# ---
# Text: Let me see what Lisa, I mean Janice said.
#   Janice (person)
# ---
# Text: I want to see new, I mean unread messages.
# ---
# Text: Can you get me all texts, no, I mean messages from today from Rob?
#   Rob (person)
# ---
# Text: What is the text, I mean email from Tom?
#   Tom (person)
# ---
# Text: Read, no I mean show the video messages from Samuel please
#   Samuel (person)
# ---
# Text: I want to hear um actually display for me the message from Katie about Susie.
#   Katie (person)
# ---
# Text: Show me my starred, I mean new messages using Whatsapp.
# ---
# Text: Please get the written, no, video message.
# ---
# Text: Read me the text, I mean email from Mal.
#   Mal (person)
# ---
# Text: Pull up texts, I mean emails from the board.
#   the (person)
#   board (person)
# ---
# Text: Could you give me text messages, no, emails for today?
# ---
# Text: Read me the audio, I mean text message please.
# ---
# Text: Please show me the message from the read, no, starred label.
# ---
# Text: Retrieve unread, actually make that archived emails.
# ---
# Text: Get my new messages from Sharon no from Tess.
#   Tess (person)
# ---
# Text: What does the Face book message from Don no Cheryl say?
#   Cheryl (person)
# ---
# Text: Read me the Facebook message from Joe, I mean Clayton.
#   Clayton (person)
# ---
# Text: Get the message from Mike, No Kenny.
#   Kenny (person)
# ---
# Text: Get me the video, no, voice message.
# ---
# Text: What did the second message from Thomas no Jake say?
#   Jake (person)
# ---
# Text: I'd like to hear my audio messages from work, I mean from my office.
#   my (person)
#   office (person)
# ---
# Text: What is the content of the email that Julian, no, wait, Julie sent me today?
#   Julie (person)
# ---
# Text: Get me all of the texts, no, I mean voice messages from this morning.
# ---
# Text: What did my boss say in his email, I mean text.
#   my (person)
#   boss (person)
# ---
# Text: Read me the email, I mean text from Robb.
#   Robb (person)
# ---
# Text: Please tell me, actually just show me, all of my new messages.
# ---
# Text: What does that text, start over, what does that chat Johnny sent me yesterday say?
#   Johnny (person)
# ---
# Text: Show me I mean tell me unread text from yesterday.
# ---
# Text: Can you read no show me the message from Dad?
#   Dad (person)
# ---
# Text: Read my last Facebook message from Bill, I mean Billy.
#   Billy (person)
# ---
# Text: Show me the message from my mom, I mean my wife.
#   my (person)
#   wife (person)
# ---
# Text: Tell me what the email says, oh I mean text
# ---
# Text: Show me the messages about the party, no the dinner party.
# ---
# Text: Show me new, I mean starred e-mails.
# ---
# Text: Read my texts, I mean emails to me please.
# ---
# Text: I'd like to see e-mails with pdf attachments, make that any document attachments.
# ---
# Text: I want to hear my new audio message on WhatsApp, no Instagram.
# ---
# Text: What was the text from Don no I mean mom.
#   mom (person)
# ---
# Text: Show me my unread Whatsapp oops I meant Outlook messages for me please.
# ---
# Text: Tell me what mary said in the text, I mean email
#   mary (person)
# ---
# Text: Show my messages about the meeting yesterday I mean today.
# ---
# Text: What is the fourth text from Nancy I mean Eric
#   Eric (person)
# ---
# Text: Show me what my grandpa said, I mean my mom.
#   my (person)
#   mom (person)
# ---
# Text: I want to see my emails, i mean my last five emails.
# ---
# Text: Read me the recent messages from Emily, um I mean, Elodie.
#   Elodie (person)
# ---
# Text: Please read the WhatsApp message from Garrett, I mean Lee.
#   Lee (person)
# ---
# Text: What does the text from fred say? I mean email
#   fred (person)
# ---
# Text: Display for me um no read out the email from last week about budget cuts.
# ---
# Text: Show the emails, actually, the audio messages.
# ---
# Text: Tell me what did Frank I mean Franky say in his email.
#   Franky (person)
# ---
# Text: Show starred email no I mean messages now
# ---
# Text: Can you show me unread WhatsApp messages from Bud, I mean Buck?
#   Buck (person)
# ---
# Text: What's the email, I mean text from Joan say?
#   Joan (person)
# ---
# Text: Read me the first three emails, I mean, messages from John.
#   John (person)
# ---
# Text: Tell me what Katie, I mean Kathryn sent me.
#   Kathryn (person)
# ---
# Text: Read me the message in Whatsapp from john i mean bob.
#   bob (person)
# ---
# Text: What is in the message from my son, I mean my wife.
#   my (person)
#   wife (person)
# ---
# Text: Find all my starred messages in Word, I'm sorry I meant Outlook.
# ---
# Text: I want to see the texts, actually emails from Bill.
#   Bill (person)
# ---
# Text: Display, no, show messages about the baby shower.
# ---
# Text: Get me the text, I mean email with the content please rsvp.
#   please (content)
#   rsvp (content)
# ---
# Text: Get my messages from July, no, August 24, 2022.
# ---
# Text: Get text err I mean audio messages from John using Facebook.
#   John (person)
# ---
# Text: Let me see emails from my boss, I mean Hotch.
#   Hotch (person)
# ---
# Text: Tell me the contents of the email i just received, actually it was a text
#   contents (content)
# ---
# Text: Tell me what's in the message, I mean text from Sue.
#   Sue (person)
# ---
# Text: Get message content from John, no, Jack.
#   Jack (person)
# ---
# Text: What did Bill say in his text, I mean email?
#   Bill (person)
# ---
# Text: I want to see the group text message my aunt sent me today, er, actually, yesterday.
#   my (person)
#   aunt (person)
# ---
# Text: Please show me my texts from Jason, no actually from John.
#   John (person)
# ---
# Text: Get new messages no emails from Stacy.
#   Stacy (person)
# ---
# Text: I want to see the text fom Louis wait no, not from him from Gilbert please.
#   Gilbert (person)
# ---
# Text: Pull up my emails from John no I mean texts from John.
#   John (person)
# ---
# Text: Display my message about the rent I mean the mortgage.
# ---
# Text: I want to see the text message mom sent me, no, dad sent me yesterday.
#   dad (person)
# ---
# Text: I want to see my messages from Julie about the play I mean the swim class.
#   Julie (person)
# ---
# Text: Show me unread WhatsApp, no, Facebook messages from Sunday.
# ---
# Text: Display starred, no, recent emails.
# ---
# Text: I need you to get the voice, wait, written message.
# ---
# Text: Read my starred, oh, I mean new messages.
# ---
# Text: Read the recent text no email from Alex.
#   Alex (person)
# ---
# Text: I need to see emails nope text messages now.
# ---
# Text: Use my iPhone no iPad to view the message.
# ---
# Text: Get new, uh sorry, starred emails.
# ---
# Text: Show me the latest messages, no, the latest emails on my iPhone.
# ---
# Text: I want to see new, I mean the audio messages.
# ---
# Text: Show me my unread Whatsapp oops I meant Outlook messages.
# ---
# Text: What did Jenny I mean Jessica just message me?
#   Jessica (person)
# ---
# Text: Show me my unread Whatsapp oops I meant Outlook messages please.
# ---
# Text: Show me the Instagram wait I mean Facebook message.
# ---
# Text: Tell me actually show me the first 3 messages from Carol.
#   Carol (person)
# ---
# Text: Pull up my texts, I mean my messages in Outlook.
# ---
# Text: Get new messages, no emails on Outlook.
# ---
# Text: What is the email, no text from Todd?
#   Todd (person)
# ---
# Text: Get me the last email from Drake, I mean Max.
#   Max (person)
# ---
# Text: What does the Twitter message from Mary, I mean, Marie say?
#   Marie (person)
# ---
# Text: What's in the message from Jess, I mean Jamie?
#   Jamie (person)
# ---
# Text: Read me my last four, I mean five messages.
# ---
# Text: Get the emails from Saturday, no I mean from Sunday.
# ---
# Text: What did Alex, I mean Andre say in his text message?
#   Andre (person)
# ---
# Text: What does that email say, I mean text
# ---
# Text: Get me the voice, no, written message.
# ---
# Text: Please open, no, read the message from Bob.
#   Bob (person)
# ---
# Text: Get that sound bite that was just sent to me through E-mail, well actually is was SMS.
# ---
# Text: What's in the email, no, text from mom?
#   mom (person)
# ---
# Text: Show no read to me my text messages.
# ---
# Text: What's in the message from June, I mean Lisa?
#   Lisa (person)
# ---
# Text: Show the message Bob sent yesterday, actually make that today.
#   Bob (person)
# ---
# Text: Display my latest Facebook, I mean WhatsApp message.
# ---
# Text: Show the message from Larry, wait, Bob.
#   Bob (person)
# ---
# Text: Tell me what the message says from Sandra, I mean Sheba.
#   Sheba (person)
# ---
# Text: I want to look at my messages on second thought read them to me.
# ---
# Text: tell me what Mindy said in her email, umm Facebook message
#   Mindy (person)
# ---
# Text: Get my recent, uh, my unread messages.
# ---
# Text: Get my new emails, no facebook messages.
# ---
# Text: Show me my unread Whatsapp oops I meant Outlook messages for me right now.
# ---
# Text: I want you to read this text, I mean email.
# ---
# Text: Get my email, no my text from mom.
#   mom (person)
# ---
# Text: Read this email oops I meant messages please.
# ---
# Text: Show me the email from today no from yesterday from Ashley.
#   Ashley (person)
# ---
# Text: Retrieve unread, I mean, starred emails with PDFs attached.
# ---
# Text: I'd like to see, I'd like to hear my newest messages on Google Mail.
# ---
# Text: Read me the first 4, no, 5 messages from Julia using Messenger.
#   Julia (person)
# ---
# Text: Show me my recent no read emails.
# ---
# Text: Bring up the text about the sales conference actually no it's an email.
# ---
# Text: What's in the message from Tom I mean Heather?
#   Heather (person)
# ---
# Text: Read out for me uh no sorry display for me the message from 10 am today.
# ---
# Text: Please tell me what did Frank I mean Franky say in his email.
#   Franky (person)
# ---
# Text: Show me the Facebook, I mean Whatsapp message from Rhett that was sent today.
#   Rhett (person)
# ---
# Text: Get me all messages, no, I mean texts from today from Rob.
#   Rob (person)
# ---
# Text: Read me the Facebook message from Bonnie, nope, from Elizabeth.
#   Elizabeth (person)
# ---
# Text: Tell me what did Frank I mean Franky say in his email please.
#   Franky (person)
# ---
# Text: Get text I mean email content.
# ---
# Text: Will you tell me what did Frank I mean Franky say in his email please?
#   Franky (person)
# ---
# Text: Read me my message um I mean email about back to school night.
# ---
# Text: Show me my unread Whatsapp oops I meant Outlook messages right now.
# ---
# Text: What's in the email from Candace I mean Mary?
#   Mary (person)
# ---
# Text: Can you get me all messages, no, I mean texts from today from Rob?
#   Rob (person)
# ---
# Text: Read the last message from Tom, oh no Todd.
#   Todd (person)
# ---
# Text: Please find the text from Pam about work, I mean about the park.
#   the (content)
#   Pam (person)
#   about (content)
#   park (content)
# ---
# Text: What did Tom say in his message? Sorry, I meant email.
#   Tom (person)
# ---
# Text: Read me the first three no four messages from Lisa.
#   Lisa (person)
# ---
# Text: Tell me what the text message, oops Facebook message from Sadie Lake sent around 10 am.
#   Sadie (person)
#   Lake (person)
# ---
# Text: Open, actually display in large font my newest email.
# ---
# Text: Can you tell me what Amy said in her message, actually, text message?
#   Amy (person)
# ---
# Text: I want to read the message my mistake Facebook message.
# ---
# Text: Get my emails with I mean without attachments.
# ---
# Text: Show me the message with the content Lunch recipes no wait Dinner Recipes.
#   Dinner (content)
#   Recipes (content)
# ---
# Text: Read me the text no the email John sent me.
#   John (person)
# ---
# Text: What did Adam send in his email, no his text?
#   Adam (person)
# ---
# Text: Read my starred, er I mean audio messages.
# ---
# Text: Show me the text Trina sent about the football, I mean the soccer game.
#   Trina (person)
# ---
# Text: Please read all new messages wait starred messages from Jane.
#   Jane (person)
# ---
# Text: Please read the email about dinner from Sydney, I mean Beth.
#   Beth (person)
# ---
# Text: Tell me who sent my latest email, I mean text.
# ---
# Text: Retrieve my unread emails with attachments, well, with photo attachments.
# ---
# Text: Show me the text, I mean email.
# ---
# Text: Get me my text messages from this morning, no yesterday morning.
# ---
# Text: Show me all emails from this week that have no, wait, that's not right, that have attachments and are from Mom.
#   Mom (person)
# ---
# Text: Tell me the text from Mom i mean Dad.
#   Dad (person)
# ---
# Text: Can I see my Facebook no Snapchat messages?
# ---
# Text: What's in that email from Tom no from John?
#   John (person)
# ---
# Text: Can you read me the text, I mean email for Mark?
#   Mark (person)
# ---
# Text: Retrieve read emails without attachments, actually, with attachments.
# ---
# Text: Read me my emails about the concert, I mean about the performance tomorrow.
# ---
# Text: What's in the email, no, text from mom from Saturday.
#   mom (person)
# ---
# Text: Give me my messages from Tuesday no wait from Wednesday.
# ---
# Text: Locate unread video mess, er, messages.
# ---
# Text: I want to I want to see the email John sent me last week.
#   John (person)
# ---
# Text: Could um Could you give me messages for this week?
# ---
# Text: Read to me my audio messages from uh yesterday.
# ---
# Text: Read me um read my unread texts please.
# ---
# Text: Show me um unread messages on Facebook.
# ---
# Text: Pull up my last 3 messages from um from Bill.
#   Bill (person)
# ---
# Text: What did Levi say in his in his email?
#   Levi (person)
# ---
# Text: What does the text text say from my husband.
#   my (person)
#   husband (person)
# ---
# Text: Read email from, from uh, Julie.
#   Julie (person)
# ---
# Text: Let's read the uh email.
# ---
# Text: Please find me my um texts please.
# ---
# Text: Show me the um message I received please.
# ---
# Text: Read the message titled The Colt's The Colt's have ran.
# ---
# Text: I want to to see the 3 texts that came in at noon.
# ---
# Text: What does the message from um from James say?
#   James (person)
# ---
# Text: Read me my um yes my texts.
# ---
# Text: Please uh tell me what my boss sent.
#   my (person)
#   boss (person)
# ---
# Text: I want to see uh my emails.
# ---
# Text: Please read my messages for for me from Kevin.
#   Kevin (person)
# ---
# Text: What is the WhatsApp message from from Brian this afternoon.
#   Brian (person)
# ---
# Text: Show me umm my unread emails.
# ---
# Text: I need to umm get my video messages.
# ---
# Text: Read me the star starred message from Andrew
#   Andrew (person)
# ---
# Text: I want to see the text from text received 10pm last night.
# ---
# Text: I'd like like to see the message Bob sent yesterday.
#   Bob (person)
# ---
# Text: Let me let me listen to the audio um audio message that was left on my voicemail.
# ---
# Text: Get my umm unread emails from Terry.
#   Terry (person)
# ---
# Text: I need to see my unread messages on on Gmail.
# ---
# Text: Show me uh messages.
# ---
# Text: Uh show me the message I received.
# ---
# Text: Read my new um my new, gmail.
# ---
# Text: Read out loud all texts from ahm last week
# ---
# Text: Let's see the most recent email from um Camilla.
#   Camilla (person)
# ---
# Text: can you um read the email with appointment in the subject
# ---
# Text: What what does the text say from my sister.
#   my (person)
#   sister (person)
# ---
# Text: Show me my starred messages on, um on WHatsapp.
# ---
# Text: What is what is in the message from um my landlord?
#   my (person)
#   landlord (person)
# ---
# Text: Umm can you get my Outlook messages about the the Sales Meeting.
# ---
# Text: Let's see my unread my unread messages on WhatsApp.
# ---
# Text: I need to have you um read audio messages.
# ---
# Text: Show me messages from um from yesterday.
# ---
# Text: Fetch me my last 3 3 messages in Facebook.
# ---
# Text: Please show me uh emails from mom.
#   mom (person)
# ---
# Text: Show me my uh emails.
# ---
# Text: Get me the last um the last email with an attachment.
# ---
# Text: Tell me what was said in the last message from umm, Brenda.
#   Brenda (person)
# ---
# Text: I want to know the um what the text from Carol says.
#   Carol (person)
# ---
# Text: Show me un unread message from Lilly please.
#   Lilly (person)
# ---
# Text: What what does the message on WhatsApp say?
# ---
# Text: Get emails from Outlook that are are starred from last month.
# ---
# Text: Uhh please read my unread my unread emails from today.
# ---
# Text: Play the audio message Christian sent, um 9pm.
#   Christian (person)
# ---
# Text: Show the starred emails in uh in Outlook.
# ---
# Text: Read my uh my recent messages.
# ---
# Text: Show me uh the message I received please.
# ---
# Text: I need to uhh see the text from Jason.
#   Jason (person)
# ---
# Text: Show me my unread messages messages on Gmail.
# ---
# Text: Uh um read read this message.
# ---
# Text: Get me starred emails in in um Gmail.
# ---
# Text: Retrieve all my um my text messages from Amazon.
#   Amazon (person)
# ---
# Text: Please read my uh my messages from yesterday.
# ---
# Text: Please get my uhh text from Steph.
#   Steph (person)
# ---
# Text: What does the what's WhatsApp message from Deck say?
#   Deck (person)
# ---
# Text: I'd like like to read my message um from 12 am.
# ---
# Text: What does the GroupMe um message from uh Jennifer say?
#   Jennifer (person)
# ---
# Text: What does the text from Kaylee what does it say?
#   Kaylee (person)
# ---
# Text: Can I see the starred emails I have uh that I have in my Gmail?
# ---
# Text: Read me the last 2 umm, messages from Daemon.
#   Daemon (person)
# ---
# Text: Show me uh yeah Show me new Whatsapp messages.
# ---
# Text: Show me uh the message I recieved.
# ---
# Text: I want to to see new email from today.
# ---
# Text: Bring up my starred the starred emails from Outlook.
# ---
# Text: I want to see any unread messages on um WhatsApp on Whatsapp.
# ---
# Text: Show me my the unread emails.
# ---
# Text: What did the umm text from Jan say?
#   Jan (person)
# ---
# Text: Can you read the email from um Joe?
#   Joe (person)
# ---
# Text: Let me see any um texts that have um screenshots attached.
# ---
# Text: Show me the uh the last 3 texts from uh um Mike.
#   Mike (person)
# ---
# Text: Help me read this, this email.
# ---
# Text: Read me the uh, text from Chris.
#   Chris (person)
# ---
# Text: Read me the um email I have open.
# ---
# Text: I would love to know what the new text I just got what it says.
# ---
# Text: Show show me the last audio message she sent.
# ---
# Text: Show me uh yeah Show me starred emails in Outlook.
# ---
# Text: Show the message it says, uh, dog vet appointment.
#   dog (content)
#   vet (content)
#   appointment (content)
# ---
# Text: Let's, let's get my unread emails.
# ---
# Text: What did Mike say say in this um email?
#   Mike (person)
# ---
# Text: Please display the mess messages about the birthday party tomorrow.
# ---
# Text: What was the recent message I just uh got
# ---
# Text: Let's see my unread messages on um Gmail.
# ---
# Text: Show me the last um the last 3 video messages.
# ---
# Text: I want to read that um email.
# ---
# Text: Retrieve the starred emails that are in in Gmail.
# ---
# Text: Read to me to me the message from Cynthia.
#   Cynthia (person)
# ---
# Text: Could you show me my um emails from yeah uh last week?
# ---
# Text: I'd like I want to get my messages from this morning.
# ---
# Text: What is in um in the email from my mom?
#   mom (person)
# ---
# Text: I want uh my emails shown.
# ---
# Text: What what does the email from Tim say?
#   Tim (person)
# ---
# Text: Can you show me unread uh messages?
# ---
# Text: Show me uh my brothers message.
#   my (person)
#   brothers (person)
# ---
# Text: Display the email um Mike sent me.
#   Mike (person)
# ---
# Text: Can you give me my me messages for the week?
# ---
# Text: Read me the first the first 3 emails from today.
# ---
# Text: I want to have you read that email from um Joe.
#   Joe (person)
# ---
# Text: Please read to me to me the umm texts messages from Jean yesterday.
#   Jean (person)
# ---
# Text: So what does the Snap Snapchat from Joe say?
#   Joe (person)
# ---
# Text: Show star um I mean started emails on Gmail
# ---
# Text: What is in the mess message from Jake?
#   Jake (person)
# ---
# Text: Let me know what Katie just sent sent me on Whatsapp.
#   Katie (person)
# ---
# Text: Please get my um my audio messages.
# ---
# Text: Show um me the uh message I emm received please.
# ---
# Text: Show the emails from my umm my Gmail account from Yesterday.
# ---
# Text: Can you read read the message from Tom Smith.
#   Tom (person)
#   Smith (person)
# ---
# Text: What is in the text from from Um alice this morning?
#   alice (person)
# ---
# Text: What does the the message um Ricky say?
#   Ricky (person)
# ---
# Text: I would like to know what uh my sister text.
#   my (person)
#   sister (person)
# ---
# Text: Show me mom's the text from mom about piano lessons.
#   mom (person)
# ---
# Text: Please look up my umm text from Jerry.
#   Jerry (person)
# ---
# Text: Get unread messages from yesterday on Yahoo mail mail.
# ---
# Text: Tell me the message from Jan from Jan from yesterday.
#   Jan (person)
# ---
# Text: Read unread emails from um today.
# ---
# Text: Read my new um my new, Telegram messages.
# ---
# Text: Show me my unread messages on my my WhatsApp.
# ---
# Text: Read me the last, the last 4 messages from Brian.
#   Brian (person)
# ---
# Text: What's in the message from umm, from Trac?
#   Trac (person)
# ---
# Text: I need uh my messages.
# ---
# Text: Read, yeah, read this email.
# ---
# Text: Show me un unread WhatsApp messages
# ---
# Text: What did um what did john say in the email?
#   john (person)
# ---
# Text: Please tell me what Stacy said in umm her text.
#   Stacy (person)
# ---
# Text: Please read me the last 2 messages from um David from David.
#   David (person)
# ---
# Text: Could you give me messages for this this week?
# ---
# Text: Show me uh yeah Show me text messages.
# ---
# Text: Can you read the uh email?
# ---
# Text: Read me my unread um emails from this week only.
# ---
# Text: Let me see what let me see the message that Greg sent me.
#   Greg (person)
# ---
# Text: Please show me my, um my Whatsapp messages.
# ---
# Text: Will you read um read the first 2 messages from Bill?
#   Bill (person)
# ---
# Text: Get my get my message on Whatsapp.
# ---
# Text: Show me what um David emailed me yesterday.
#   David (person)
# ---
# Text: Show me uh yeah Show me new Telegram messages.
# ---
# Text: Read my new um my new, Facebook messages.
# ---
# Text: I would like to know what my uh dad text.
#   dad (person)
# ---
# Text: What did mom say, did mom say in her text?
#   mom (person)
# ---
# Text: Get my uhh new audio message from Dan.
#   Dan (person)
# ---
# Text: Read me the um message from Guthrie on Facebook.
#   Guthrie (person)
# ---
# Text: Tell me what uh what that Whatsapp message from John says.
#   John (person)
# ---
# Text: Let's read my star umm my starred messages from the past week.
# ---
# Text: I need to see my um texts.
# ---
# Text: Please um please get me my WhatsApp messages.
# ---
# Text: Read me my Facebook messages um from Sunday.
# ---
# Text: Could you um give me emails for um this week?
# ---
# Text: Um My Facebook message from Jessica needs to be brought up and replied to please.
#   Jessica (person)
# ---
# Text: I'd like to see what what Kyran said in his message via Messenger.
#   Kyran (person)
# ---
# Text: Can you um, can you get um, audio messages from mom?
#   mom (person)
# ---
# Text: I need to hear the uh audio message from my wife.
#   my (person)
#   wife (person)
# ---
# Text: Tell me what was said in the last message from umm, Miley.
#   Miley (person)
# ---
# Text: Display the text Mike um sent me this morning.
#   Mike (person)
# ---
# Text: Get get my text messages.
# ---
# Text: Show me um the message I received please.
# ---
# Text: Show all ah, mess messages from this this morning.
# ---
# Text: I would like to see the uh message.
# ---
# Text: Find the email sent sent yesterday with a PDF attached.
# ---
# Text: Show me what's in in the message.
# ---
# Text: What's in the email from from um Tony?
#   Tony (person)
# ---
# Text: Read my uh message.
# ---
# Text: Can you read the um read my audio messages?
# ---
# Text: I want the text from my wife uh shown.
#   my (person)
#   wife (person)
# ---
# Text: Let's get get the new um new emails.
# ---
# Text: Play the video message Christian sent um 5am.
#   Christian (person)
# ---
# Text: Please get my umm unread emails from Greg.
#   Greg (person)
# ---
# Text: Tell me please what the email email the starred email says from my sister from May 20th.
#   my (person)
#   sister (person)
# ---
# Text: What does the the message from Jakey say?
#   Jakey (person)
# ---
# Text: Let me see the uh message from um Daniel about um the cornhole tournament.
#   Daniel (person)
# ---
# Text: Uh um can you read to me what Joe said in his um text?
#   Joe (person)
# ---
# Text: Show read text messages.
# ---
# Text: Let me hear the audio message from Taylor.
#   Taylor (person)
# ---
# Text: Can you read my audio message from Chad?
#   Chad (person)
# ---
# Text: get newest messages
# ---
# Text: Display message from Susan.
#   Susan (person)
# ---
# Text: Get me the video message from yesterday.
# ---
# Text: Show me any messages with attachments from today.
# ---
# Text: Please read me the audio message from Bruce.
#   Bruce (person)
# ---
# Text: What was in my first message this morning?
# ---
# Text: Display messages from WhatsApp
# ---
# Text: Display new communications from WhatsApp.
# ---
# Text: Please play my messages for me.
# ---
# Text: Get all junk messages.
# ---
# Text: Retrieve starred messages.
# ---
# Text: Show me the Instagram messages from Thomas.
#   Thomas (person)
# ---
# Text: What did Joshua say in his text message?
#   Joshua (person)
# ---
# Text: I need you to read new messages from tony please.
#   tony (person)
# ---
# Text: I want to hear the last message I received.
# ---
# Text: Show the last message in Google Duo
# ---
# Text: Show the message from Friday.
# ---
# Text: Please get the message I received from work at noon today.
# ---
# Text: Get me new messages.
# ---
# Text: Read me the message I received on Facebook.
# ---
# Text: Read the last message from Mr. Thompson
#   Thompson (person)
# ---
# Text: Can you show me the message from mom on Twitter?
#   mom (person)
# ---
# Text: Show me the message from John.
#   John (person)
# ---
# Text: Please read my message from Jack.
#   Jack (person)
# ---
# Text: What does the WhatsApp message from Matthew say?
#   Matthew (person)
# ---
# Text: I'd like to see the messages from my sister about the birthday party scheduled for next week.
#   my (person)
#   sister (person)
# ---
# Text: Read me the unread text from dad.
#   dad (person)
# ---
# Text: Show me the unread message from our parents.
#   our (person)
#   parents (person)
# ---
# Text: Show starred emails in Gmail.
# ---
# Text: Retrieve starred emails from yesterday.
# ---
# Text: Display unread messages on Instagram.
# ---
# Text: gather newest messages
# ---
# Text: read me the latest message from Ryan in facebook
#   Ryan (person)
# ---
# Text: Read me the message from Jim.
#   Jim (person)
# ---
# Text: Can you please tell me what James said in his message?
#   James (person)
# ---
# Text: What is in the message from Karen from work?
#   Karen (person)
# ---
# Text: Show me the message from Jim.
#   Jim (person)
# ---
# Text: Please get recent messages in Outlook.
# ---
# Text: I want to see unread messages.
# ---
# Text: Can you read aloud the last whatsapp mesaage from Dad
#   Dad (person)
# ---
# Text: I need to read the email I got from Abby on Monday.
#   Abby (person)
# ---
# Text: Show me my new messages.
# ---
# Text: Tell me what was said in the text message.
# ---
# Text: read me the latest message from Ryan in signal
#   Ryan (person)
# ---
# Text: Show me the messages from Zac's teacher about what supplies he needs for school.
#   Zac's (person)
#   teacher (person)
#   supplies (content)
#   needs (content)
#   for (content)
#   school (content)
# ---
# Text: Can you read aloud the last imessage from Dad
#   Dad (person)
# ---
# Text: Show me the text message from mom.
#   mom (person)
# ---
# Text: Read the first message from Sally.
#   Sally (person)
# ---
# Text: Read the last three emails in my inbox
# ---
# Text: Please display the text from Harry.
#   Harry (person)
# ---
# Text: Retrieve recent messages.
# ---
# Text: Display emails with videos in Google Mail.
# ---
# Text: Let's see my starred emails in Gmail please.
# ---
# Text: Will you read my message from Jack?
#   Jack (person)
# ---
# Text: Display all text messages that I received today.
# ---
# Text: Tell me my recent messages
# ---
# Text: Please display flagged emails in Outlook.
# ---
# Text: Get me text with the content call back soon
#   call (content)
#   back (content)
#   soon (content)
# ---
# Text: Read archive messages.
# ---
# Text: Show me my read messages.
# ---
# Text: Read me the message Mike sent me.
#   Mike (person)
# ---
# Text: Please show me the message from Jane.
#   Jane (person)
# ---
# Text: Get starred emails on Gmail.
# ---
# Text: Show me unread work emails on Outlook
# ---
# Text: Let's see my starred emails in Gmail now.
# ---
# Text: I need to hear the message on Twitter from Harry Ponce.
#   Harry (person)
#   Ponce (person)
# ---
# Text: Read that message out loud.
# ---
# Text: Retrieve all my work messages from Slack.
# ---
# Text: Show me the most recent message
# ---
# Text: Please read my video messages.
# ---
# Text: What did Bob say in his text messages?
#   Bob (person)
# ---
# Text: Show video message on Instagram.
# ---
# Text: What does the email from Steven say?
#   Steven (person)
# ---
# Text: Show me emails with attachments for next week.
# ---
# Text: Can you show me the email Mike sent me?
#   Mike (person)
# ---
# Text: Please announce last weeks emails that were marked as important.
# ---
# Text: What does the Telegram message from Pernell say?
#   Pernell (person)
# ---
# Text: Read me my Hangouts message from Carol
#   Carol (person)
# ---
# Text: Show me the email from Gabriel.
#   Gabriel (person)
# ---
# Text: I want to see my new email.
# ---
# Text: Display all starred messages in my Gmail.
# ---
# Text: Display the starred emails in Gmail.
# ---
# Text: Now read that message out loud.
# ---
# Text: Please show me starred emails in Outlook.
# ---
# Text: Bring up recent message for me
# ---
# Text: I want to see the text message Ander sent me today.
#   Ander (person)
# ---
# Text: Read all my saved audio messages from last week.
# ---
# Text: Please show me the messages from Jen about the Bachelorette party plans.
#   Jen (person)
# ---
# Text: Show the read message.
# ---
# Text: What does the Facebook message from Laura say?
#   Laura (person)
# ---
# Text: Read the last two Facebook messages from Bridget.
#   Bridget (person)
# ---
# Text: Read this new message please.
# ---
# Text: Show unread messages on WhatApp business.
# ---
# Text: Read the texts from last week.
# ---
# Text: Show me all the messages from this week about the fair.
# ---
# Text: What did the whatsapp message from Jen say?
#   Jen (person)
# ---
# Text: Open unread messages from today
# ---
# Text: Please show me the messages from my mom about the funeral.
#   mom (person)
# ---
# Text: What's in the message from Jayden?
#   Jayden (person)
# ---
# Text: I want to watch my video messages.
# ---
# Text: I need to review the messages about the online zoom event this week.
# ---
# Text: Bring up my last message please
# ---
# Text: I would like to hear messages from the committee that came in on Skype today.
#   committee (person)
# ---
# Text: Show me emails with pictures attached in Gmail.
# ---
# Text: Display me the message from John.
#   John (person)
# ---
# Text: What did the email from Sam say?
#   Sam (person)
# ---
# Text: Can you please show me what Clayton said in his text?
#   Clayton (person)
# ---
# Text: I want to see messages from last Wednesday.
# ---
# Text: Read me the email Mike sent me.
#   Mike (person)
# ---
# Text: Get voice messages for today
# ---
# Text: What did Anna say in her message on Twitter?
#   Anna (person)
# ---
# Text: Show me my text messages from the past hour.
# ---
# Text: Please show me the email from Kate.
#   Kate (person)
# ---
# Text: Read this text message
# ---
# Text: Tell me what is in that message from Ken.
#   Ken (person)
# ---
# Text: I want to see the email Mike sent me.
#   Mike (person)
# ---
# Text: Tell me what is in the message from Susan?
#   Susan (person)
# ---
# Text: What does my new WhatsApp message say?
# ---
# Text: Retrieve all unread messages
# ---
# Text: See this email.
# ---
# Text: Can you read me John's message?
#   John's (person)
# ---
# Text: Read me the email Bob sent me.
#   Bob (person)
# ---
# Text: Can you show me my messages?
# ---
# Text: Can you please read my message from Jack?
#   Jack (person)
# ---
# Text: Show me unread messages on Instagram.
# ---
# Text: Will you read my unread audio messages?
# ---
# Text: I need to see the message about the work party tomorrow.
#   work (content)
#   party (content)
# ---
# Text: Show me the unread video facebook message.
# ---
# Text: What does that message from Marley say?
#   Marley (person)
# ---
# Text: Display the video message from Brittany.
#   Brittany (person)
# ---
# Text: Could you tell me what's in that message from Tom.
#   Tom (person)
# ---
# Text: Let's hear my new WhatsApp message.
# ---
# Text: Read my Messenger messages from my husband.
#   husband (person)
# ---
# Text: What's in the message I just got?
# ---
# Text: Please show me text messages from chloe on Saturday
#   chloe (person)
# ---
# Text: Show me the last 2 starred emails on Gmail.
# ---
# Text: What does the email from work say?
#   work (person)
# ---
# Text: Can you show me my message from Joey?
#   Joey (person)
# ---
# Text: Show me the last ten messages from Brook.
#   Brook (person)
# ---
# Text: Read me the text from Sharon.
#   Sharon (person)
# ---
# Text: Show me the contents of that message I got last year on Christmas.
# ---
# Text: Show me my texts from my mom.
#   my (person)
#   mom (person)
# ---
# Text: What's in the recent message from Heather?
#   Heather (person)
# ---
# Text: Read out all the facebook messages
# ---
# Text: Show me the unread emails in Outlook.
# ---
# Text: I need to view the email from Terry that had an attachment.
#   Terry (person)
# ---
# Text: Please read to me the messages I received this morning
# ---
# Text: I need to hear the email that Fred sent.
#   Fred (person)
# ---
# Text: Show me my messages from Josh
#   Josh (person)
# ---
# Text: Show this email.
# ---
# Text: Can you tell me what Randy said in his message?
#   Randy (person)
# ---
# Text: Get my last text from my brother.
#   my (person)
#   brother (person)
# ---
# Text: What did the Instagram message from Mom say?
#   Mom (person)
# ---
# Text: Read all messages received since last night.
# ---
# Text: Read the first email from today.
# ---
# Text: Could you please read my new WhatsApp message?
# ---
# Text: Show me the message Mike gave me on Thursday.
#   Mike (person)
# ---
# Text: Get new emails please
# ---
# Text: I want to see all Facebook messages.
# ---
# Text: Show me the unread Gmail emails.
# ---
# Text: What does the work email with training meeting in the subject say
#   training (content)
#   meeting (content)
# ---
# Text: Show all starred messages.
# ---
# Text: I want to see all unread messages from this week.
# ---
# Text: Read my last three emails from today in Gmail.
# ---
# Text: Read aloud unread emails from today.
# ---
# Text: Retrieve the third message from grandma.
#   grandma (person)
# ---
# Text: Show me the email from John.
#   John (person)
# ---
# Text: Can you show me the video message from Robert?
#   Robert (person)
# ---
# ...
# ---
# Text: Post to uh to Reddit.
# ---
# Text: My LinkedIn status needs um needs updated.
# ---
# Text: Post that um I won on Facebook.
# ---
# Text: Update my Facebook status to uh 'Proud owner of a new Jeep'.
# ---
# Text: Update my my LiveJournal.
# ---
# Text: Post on Facebook that I am single yeah single.
# ---
# Text: Make a a Twitter Post.
# ---
# Text: Make a Twitter a Twitter post
# ---
# Text: Create a post to create a post on Twitter.
# ---
# Text: I'd like to update my LinkedIn status to uh looking for employment
# ---
# Text: Update my my Twitter account.
# ---
# Text: um tweet my current status as living the dream
# ---
# Text: Update, all update all posts on Facebook.
# ---
# Text: I uh want to update TikTok.
# ---
# Text: A post on LinkedIn I need to post on LinkedIn.
# ---
# Text: I want to post a a new message.
# ---
# Text: Update Facebook with update Facebook with 'I'm having a great day today'.
# ---
# Text: I want to want to update the Instagram post.
# ---
# Text: I'd like um like to post a message.
# ---
# Text: Make a um update to my Facebook.
# ---
# Text: Let's um let's update my LinkedIN status.
# ---
# Text: Post on Facebook, post on Facebook the news report.
# ---
# Text: Tweet uh tweet using Twitter.
# ---
# Text: Make a a post on Twitter stating I got a new car.
# ---
# Text: I want to post on Twitter that um I won.
# ---
# Text: Update Facebook with update Facebook with 'we won'.
# ---
# Text: Update the job description on, on Linkedin.
# ---
# Text: Use Twitter to announce, I's it's a boy!'.
# ---
# Text: Facebook status, updated update it now.
# ---
# Text: On Facebook book, post a picture of this sunset,
# ---
# Text: Post on Facebook Facebook with 'i need a dog'.
# ---
# Text: Tweet that I am single yeah single.
# ---
# Text: I need to make a, make a post saying 'It's my birthday!'.
# ---
# Text: Post on Instagram, post on Instagram about the wedding.
# ---
# Text: Tweet out my out my current status.
# ---
# Text: Tweet my current status my current status.
# ---
# Text: Post an Instagram um status yeah status update.
# ---
# Text: Post on on Facebook.
# ---
# Text: I want to um tweet a message saying that I won.
# ---
# Text: Create a new face Facebook status update saying 'new month in a bit'
# ---
# Text: Use Twitter to to post pictures of the go goats for sale.
# ---
# Text: Share a new status to my to my Facebook.
# ---
# Text: I want to post an update to my um LinkedIn saying Who is hiring right now?
# ---
# Text: Update my LinkedIn status to uh full time teacher.
# ---
# Text: Make a um, a new post to Facebook.
# ---
# Text: Post a tweet that we're we're moving today.
# ---
# Text: I want to post on uh Twitter.
# ---
# Text: Change my um Facebook status from in a relationship to uh married.
# ---
# Text: Can I tweet a new um message?
# ---
# Text: Post a message a message on facebook about the party.
# ---
# Text: Post 'happy', um, 'happy birthday, Kelly' to Facebook.
# ---
# Text: Post new a new message on tiktok.
# ---
# Text: Tweet it's tweet it's been a day.
# ---
# Text: Please go ahead and change my uh status.
# ---
# Text: Post a new status a new status update please.
# ---
# Text: Post a post a new tweet.
# ---
# Text: Let's update um Linkedin with um I won the lotto!
# ---
# Text: Would you please create um create a new post on Facebook?
# ---
# Text: Post um please post a message on Instagram for me.
# ---
# Text: I'd like to to update my Facebook status.
# ---
# Text: Tweet tweet have a fabulous day!
# ---
# Text: Post to facebook umm look out here comes trouble it was twin boys
# ---
# Text: Post a message on my um Facebook saying hurricane party.
# ---
# Text: I want to want to update the Twitter post.
# ---
# Text: Crear post en LinkedIn.
# ---
# Text: Can you post Jesus Christus starb für dich on my Facebook wall?
# ---
# Text: Can you update Facebook with we won?
# ---
# Text: Poster on Facebook.
# ---
# Text: Make a new post in LinkedIn.
# ---
# Text: Poste ein Facebook status update.
# ---
# Text: I want a new post on my Facebook लिखी जाए.
# ---
# Text: I want to tweet Here’s my 焼肉 lunch.
# ---
# Text: Create Xing Beitrag.
# ---
# Text: Post a message on my Facebook wall that says Menuda experiencia en la playa.
# ---
# Text: Tweeter a new message.
# ---
# Text: Write Bravo Julie on Twitter.
# ---
# Text: Create a new post on Facebook saying Mama ist die Beste!
# ---
# Text: Update my statut Facebook.
# ---
# Text: Can you post Les Fleurs Bleues by Raymond Queneau is my favourite book?
# ---
# Text: Update my estado on Facebook.
# ---
# Text: Ändere my Facebook status to passed my exam.
# ---
# Text: Change my Facebook status to 'available'.
# ---
# Text: Can you please update my current estado?
# ---
# Text: Post a new संदेश.
# ---
# Text: Post a new mensaje.
# ---
# Text: Poster un status update sur Facebook.
# ---
# Text: I want to post a message on Facebook that says Bon voyage.
# ---
# Text: Quiero que actualices my status in Facebook saying The humidity is unbearable.
# ---
# Text: Poste ein Status Update.
# ---
# Text: En LinkedIn crear nueva publicación que diga Estamos contratando abogados en nuestra sede de Barcelona.
# ---
# Text: Create a new post on Facebook saying Frohe Weihnachten an alle.
# ---
# Text: @ सुशील कुमार Tweet करो।
# ---
# Text: Make a Twitter Beitrag.
# ---
# Text: I'd like to write Vive les Bleus on Twitter.
# ---
# Text: Je veux actualiser mon statut LinkedIn et dire Ich bin verreist.
# ---
# Text: Write a note on Google Keep
# ---
# Text: Create a note on Google Keep
# ---
# Text: I want to start a new note
# ---
# Text: Pull a new note up
# ---
# Text: create a note on my apple notes
# ---
# Text: create a note
# ---
# Text: I want to write a note
# ---
# Text: Pickup pizza for dinner tonight.
#   Pickup (content)
#   pizza (content)
#   for (content)
#   dinner (content)
#   tonight (content)
#   . (content)
# ---
# Text: New note
# ---
# Text: Need to find new toys for Spot
#   Need (content)
#   to (content)
#   find (content)
#   new (content)
#   toys (content)
#   for (content)
#   Spot (content)
# ---
# Text: Let's start a new note on my iPhone
# ---
# Text: Renew gym membership before it expires
#   Renew (content)
#   gym (content)
#   membership (content)
#   before (content)
#   it (content)
#   expires (content)
# ---
# Text: write a note to Bobby
#   Bobby (person)
# ---
# Text: create a note
# ---
# Text: create a note on my ipod
# ---
# Text: download new album July 3
#   download (content)
#   new (content)
#   album (content)
#   July (content)
#   3 (content)
# ---
# Text: create a note
# ---
# Text: pick up food at 7
#   pick (content)
#   up (content)
#   food (content)
#   at (content)
#   7 (content)
# ---
# Text: write a note to Gary
#   Gary (person)
# ---
# Text: Would you start a note?
# ---
# Text: Make a note.
# ---
# Text: Dinner at 7pm.
#   Dinner (content)
#   at (content)
#   7pm (content)
#   . (content)
# ---
# Text: Write a note using Apple notes
# ---
# Text: create a note
# ---
# Text: Create a note for my Apple Notes
# ---
# Text: Write a note on my phone
# ---
# Text: Write a note to the Headmaster.
#   the (person)
#   Headmaster (person)
# ---
# Text: Remember to call the power company about the issue with the bill.
#   Remember (content)
#   to (content)
#   call (content)
#   the (content)
#   power (content)
#   company (content)
#   about (content)
#   issue (content)
#   with (content)
#   bill (content)
#   . (content)
# ---
# Text: Save a note on my phone.
# ---
# Text: write a note to parker
#   parker (person)
# ---
# Text: create new note on ipod
# ---
# Text: pick up groceries at 6
# ---
# Text: write a new note
# ---
# Text: Create a note
# ---
# Text: Create a note on my iPad
# ---
# Text: Write a note on Apple notes
# ---
# Text: Reschedule Bi-Pap Fitting for Jerry.
#   Reschedule (content)
#   Bi-Pap (content)
#   Fitting (content)
#   for (content)
#   Jerry (content)
#   . (content)
# ---
# Text: Create note in Notepad App
# ---
# Text: Create note
# ---
# Text: write a note in Apple Notes
# ---
# Text: make a note on Google Keep
# ---
# Text: create a new note for me
# ---
# Text: Create a note
# ---
# Text: Hi Mary. Great to see you yesterday
#   Hi (content)
#   Mary (content)
#   . (content)
#   Great (content)
#   to (content)
#   see (content)
#   you (content)
#   yesterday (content)
# ---
# Text: can you make a note
# ---
# Text: create a note on my phone
# ---
# Text: create new note for evan
#   evan (person)
# ---
# Text: Create a note
# ---
# Text: Create a note
# ---
# Text: Call eye doctor about prescription
#   Call (content)
#   eye (content)
#   doctor (content)
#   about (content)
#   prescription (content)
# ---
# Text: Call National Jewish for labs.
#   Call (content)
#   National (content)
#   Jewish (content)
#   for (content)
#   labs (content)
#   . (content)
# ---
# Text: cheeze-its are great
#   cheeze-its (content)
#   are (content)
#   great (content)
# ---
# Text: count the number of carrots
#   count (content)
#   the (content)
#   number (content)
#   of (content)
#   carrots (content)
# ---
# Text: make a note for my laptop
# ---
# Text: create a note saying dinner tomorrow at 7
#   dinner (content)
#   tomorrow (content)
#   7 (content)
# ---
# Text: Make a note for 3pm.
# ---
# Text: Actually, make it 3:30pm.
# ---
# Text: Save a note for 3pm please
# ---
# Text: Could you write a note for Jim on my iPhone
#   Jim (person)
# ---
# Text: Sorry make it 4pm instead
# ---
# Text: I want to write a note for someone
# ---
# Text: Write it for Jim
#   Jim (person)
# ---
# Text: I want to write a note for Susie
#   Susie (person)
# ---
# Text: Actually I want that note for Bobbie
#   Bobbie (person)
# ---
# Text: Please start a new note for Amelia
#   Amelia (person)
# ---
# Text: Actually switch that note to Taylor
#   Taylor (person)
# ---
# Text: Please scribe a note to Maya
#   Maya (person)
# ---
# Text: make a note
# ---
# Text: Pay power bill Thursday
#   Pay (content)
#   power (content)
#   bill (content)
#   Thursday (content)
# ---
# Text: create a note on my laptop
# ---
# Text: Class starts in 4 hours
#   Class (content)
#   starts (content)
#   in (content)
#   4 (content)
#   hours (content)
# ---
# Text: Vacation starts in 5 days
#   Vacation (content)
#   starts (content)
#   in (content)
#   5 (content)
#   days (content)
# ---
# Text: I want to write a note for Jim
#   Jim (person)
# ---
# Text: Bring the notes for the meeting with you
#   Bring (content)
#   the (content)
#   notes (content)
#   for (content)
#   meeting (content)
#   with (content)
#   you (content)
# ---
# Text: Oh, can you write that note for John instead
#   John (person)
# ---
# Text: Bring the notes for the meeting with you
#   Bring (content)
#   the (content)
#   notes (content)
#   for (content)
#   meeting (content)
#   with (content)
#   you (content)
# ---
# Text: Save a note on Apple Notes please
# ---
# Text: Could you start a new note to Mark
#   Mark (person)
# ---
# Text: New note to Mark
#   Mark (person)
# ---
# Text: Please change that note from Justin to Matthew
#   Matthew (person)
# ---
# Text: Detail on the car is finished
#   Detail (content)
#   on (content)
#   the (content)
#   car (content)
#   is (content)
#   finished (content)
# ---
# Text: Read The Long Dark Pages 22-25
#   Read (content)
#   The (content)
#   Long (content)
#   Dark (content)
#   Pages (content)
#   22-25 (content)
# ---
# Text: create a note on my ipad
# ---
# Text: create a note on duo
# ---
# Text: sorry can you create a note on alexa instead
# ---
# Text: Add carrots to the grocery list
#   Add (content)
#   carrots (content)
#   to (content)
#   the (content)
#   grocery (content)
#   list (content)
# ---
# Text: Let's make a note for 3pm
# ---
# Text: Let's make a note on my phone
# ---
# Text: Remember to pickup Bob at the airport at 3pm
#   Remember (content)
#   to (content)
#   pickup (content)
#   Bob (content)
#   at (content)
#   the (content)
#   airport (content)
#   3pm (content)
# ---
# Text: Write it on Apple Notes instead
# ---
# Text: Wait I want to change that to my pixel
# ---
# Text: Please save a new note for Matthew
#   Matthew (person)
# ---
# Text: Only red paint needed
#   Only (content)
#   red (content)
#   paint (content)
#   needed (content)
# ---
# Text: Actually change that note to my iPhone
# ---
# Text: Start a new note on notes app
# ---
# Text: Oops I meant the apple notes
# ---
# Text: Start a new note for Debbie
#   Debbie (person)
# ---
# Text: Stop change the note to Mark
#   Mark (person)
# ---
# Text: make a note on my iphone
# ---
# Text: sorry make a note on google instead
# ---
# Text: make a note on my iphone for Sam
#   Sam (person)
# ---
# Text: create a note on google keep
# ---
# Text: sorry please create a note on onenote instead
# ---
# Text: Write a note for Mike
#   Mike (person)
# ---
# Text: I love you
#   I (content)
#   love (content)
#   you (content)
# ---
# Text: Write a note for Matt
#   Matt (person)
# ---
# Text: Create a note on my iPhone
# ---
# Text: Actually make it on Notes app
# ---
# Text: Write a note that says pick up kids at 4 pm
#   pick (content)
#   up (content)
#   kids (content)
#   4 (content)
#   pm (content)
# ---
# Text: New note on Apple notes
# ---
# Text: Change 2 pm to 3 pm
# ---
# Text: make a note on my phone about lunch tomorrow
# ---
# Text: create a note for Casey
#   Casey (person)
# ---
# Text: create a note on duo
# ---
# Text: make a note o the laptop
# ---
# Text: create a note on apple notes
# ---
# Text: sorry can you create it on my ipad instead
# ---
# Text: sorry can you make a note on my iphone instead
# ---
# Text: conference call at 2 p.m.
#   conference (content)
#   call (content)
#   at (content)
#   2 (content)
# ---
# Text: sorry can you create the note on google instead
# ---
# Text: Create a note for Dan
#   Dan (person)
# ---
# Text: You're the best
#   You're (content)
#   the (content)
#   best (content)
# ---
# Text: Go to Target
#   Go (content)
#   to (content)
#   Target (content)
# ---
# Text: Can you create that note on my iPhone instead
# ---
# Text: Write it on my iPad instead
# ---
# Text: Put that on Notes app instead
# ---
# Text: make a note for my laptop
# ---
# Text: actually, make that note for Kate
#   Kate (person)
# ---
# Text: create a note for Christi
#   Christi (person)
# ---
# Text: no, please write it for my phone
# ---
# Text: create a note for Kathie on my phone notes
#   Kathie (person)
# ---
# Text: Create a note on the Notes app
# ---
# Text: Can you create it on Apple notes instead?
# ---
# Text: Write that note to Cole instead of Brady
#   Cole (person)
# ---
# Text: actually write it in Apple Notes
# ---
# Text: create a note for Kasey
#   Kasey (person)
# ---
# Text: sorry, please create it for Naomi
#   Naomi (person)
# ---
# Text: write a note in Apple Notes
# ---
# Text: buy contacts next month
#   buy (content)
#   contacts (content)
#   next (content)
#   month (content)
# ---
# Text: actually, make it for 11:30
# ---
# Text: sorry could you create a note on my tablet instead.
# ---
# Text: pick up concert tickets tomorrow
#   pick (content)
#   up (content)
#   concert (content)
#   tickets (content)
#   tomorrow (content)
# ---
# Text: sorry can you change that to pick up Kennedi at 12
#   pick (content)
#   up (content)
#   Kennedi (content)
#   12 (content)
# ---
# Text: Change that and make a note on Alexa instead.
# ---
# Text: Pick up groceries for party Saturday
#   Pick (content)
#   up (content)
#   groceries (content)
#   for (content)
#   party (content)
#   Saturday (content)
# ---
# Text: sorry can you create it on my iphone instead
# ---
# Text: Start a note to David.
#   David (person)
# ---
# Text: Create for me a note to Sarah.
#   Sarah (person)
# ---
# Text: Create a note for Sara
#   Sara (person)
# ---
# Text: Write a note for Sammie.
#   Sammie (person)
# ---
# Text: Clean up your toys!
#   Clean (content)
#   up (content)
#   your (content)
#   toys (content)
#   ! (content)
# ---
# Text: Leave a note for Katharyn
#   Katharyn (person)
# ---
# Text: I wanna note this down.
# ---
# Text: Write a new note tomorrow at 7a.m.
# ---
# Text: Start for me a new note on my Android phone.
# ---
# Text: Make a note on my Android phone.
# ---
# Text: Can you write this down, please?
# ---
# Text: Write a new note on my iPad.
# ---
# Text: I want to make a note for 7 am
# ---
# Text: Create a note on my iPad
# ---
# Text: save a note for me
# ---
# Text: Create a note at 6pm
# ---
# Text: Create a note for 1pm
# ---
# Text: Stop
# ---
# Text: Write a note at 4am
# ---
# Text: Nevermind
# ---
# Text: Make a note for me
# ---
# Text: Start a new note for 4 pm
# ---
# Text: Write note at noon
# ---
# Text: make a note
# ---
# Text: write down a note
# ---
# Text: please save a note for me
# ---
# Text: can you put a note on my ipad
# ---
# Text: make a note for later
# ---
# Text: can you leave a note for later
# ---
# Text: Begin new note
# ---
# Text: Make a new note
# ---
# Text: New note now
# ---
# Text: Start note for Tom
#   Tom (person)
# ---
# Text: Create a note
# ---
# Text: Write a note on my iPad
# ---
# Text: Write a note on my iPad
# ---
# Text: Take down a note.
# ---
# Text: Make a new note
# ---
# Text: Add note
# ---
# Text: Add note
# ---
# Text: Add a note please
# ---
# Text: make a note
# ---
# Text: Add a note for Rachel
#   Rachel (person)
# ---
# Text: add a note
# ---

# %%
import pandas as pd

# Load the test.csv dataset to inspect its structure
test_csv_path = 'test.csv'
test_df = pd.read_csv(test_csv_path)

# Display the first few rows of the dataframe to understand its structure
test_df.head()

# Define a function to preprocess the test data from test.csv
def preprocess_test_data(df):
    sentences = df['sentence'].tolist()
    # Convert 'labels' and 'words' from string representation of list to actual lists
    entities_data = []
    for _, row in df.iterrows():
        words = eval(row['words'])
        labels = eval(row['labels'])
        entities = []
        for word, label in zip(words, labels):
            if label != 0:  # Assuming '0' means 'no entity'
                entities.append((word, label))
        entities_data.append(entities)
    return sentences, entities_data

# Preprocess the test data to extract entities
sentences, ground_truth_entities = preprocess_test_data(test_df)

# Show an example of the preprocessed data
sentences[0], ground_truth_entities[0]
# Out:
# ('Create a 6 pm note in Notas.', [])

# %%
import spacy

# Load your trained spaCy model
nlp_trained = spacy.load("./output/model-best")

predicted_entities = []
for sentence in sentences:
    # Process each sentence through the model
    doc = nlp_trained(sentence)
    # Extract predicted entities
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    predicted_entities.append(entities)

# %%
from collections import Counter

def calculate_metrics(predicted_entities, ground_truth_entities):
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    
    for predicted, true in zip(predicted_entities, ground_truth_entities):
        predicted_counter = Counter(predicted)
        true_counter = Counter(true)
        
        true_positives += sum((predicted_counter & true_counter).values())
        false_positives += sum((predicted_counter - true_counter).values())
        false_negatives += sum((true_counter - predicted_counter).values())
    
    precision = true_positives / (true_positives + false_positives) if true_positives + false_positives > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
    
    return precision, recall, f1_score

# Calculate the evaluation metrics
precision, recall, f1_score = calculate_metrics(predicted_entities, ground_truth_entities)

print(f"Precision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")
# Out:
# Precision: 0.8300104931794333
# Recall: 0.7427230046948357
# F1 Score: 0.78394449950446

# %%
print(ground_truth_entities)
# Out:
# [[], [], [('María', 'person')], [('Bob', 'person')], [], [('Mitbringbuffet', 'content'), ('am', 'content'), ('Mittwoch', 'content')], [('Mama', 'person')], [('get', 'content'), ('kid', 'content'), ('son', 'content'), ('aus', 'content'), ('dem', 'content'), ('Kindergarten', 'content')], [], [], [('buy', 'content'), ('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('Love', 'content'), ('and', 'content'), ('other', 'content'), ('drugs', 'content')], [('François', 'person')], [], [], [('reunión', 'content'), ('12:30', 'content')], [('Hélène', 'person'), ('Gérard', 'person')], [], [], [('mamá', 'person')], [('Roberto', 'person')], [('太郎', 'person')], [], [('Anna', 'person')], [], [('buy', 'content'), ('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('私', 'person')], [], [('パパ', 'person')], [('buy', 'content'), ('chocolate', 'content')], [], [], [], [], [], [], [('book', 'content'), ('the', 'content'), ('flight', 'content'), ('to', 'content'), ('Bordeaux', 'content')], [], [], [], [], [('Bunny', 'person')], [], [], [], [('my', 'person'), ('Vater', 'person')], [('papá', 'person')], [], [], [('Hafermilch', 'content'), ('kaufen', 'content')], [('Abendessen', 'content')], [], [], [('fiesta', 'content'), ('esta', 'content'), ('noche', 'content')], [], [], [], [], [('love', 'content'), ('you', 'content')], [], [('María', 'person')], [('Dad', 'person')], [('भाई', 'person')], [('Papa', 'person')], [], [], [('sortir', 'content'), ('les', 'content'), ('poubelles', 'content')], [('buy', 'content'), ('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('Bob', 'person')], [], [('mamá', 'person')], [], [], [('barbecue', 'content'), ('at', 'content'), ("Marie-Cécile's", 'content'), ('on', 'content'), ('Sunday', 'content')], [], [('Hildegard', 'person')], [], [('Julien', 'person'), ('Leclerc', 'person')], [], [], [('Nathalie', 'person'), ('Bonnet', 'person'), ('the', 'content'), ('village', 'content'), ('fête', 'content')], [], [('Olivier', 'person')], [('the', 'content'), ('shopping', 'content'), ('list', 'content')], [('Bob', 'person')], [('Bobs', 'person')], [('Bob', 'person')], [('Amita', 'person'), ('his', 'content'), ('family', 'content'), ('emergency', 'content')], [], [], [], [], [('Juan', 'person')], [('Pierre', 'person')], [], [('Mike', 'person')], [], [], [], [], [], [], [('ケント', 'person')], [], [('please', 'content'), ('rsvp', 'content'), ('below', 'content')], [('please', 'content'), ('handle', 'content'), ('with', 'content'), ('care', 'content')], [('Tom', 'person')], [('Ángela', 'person')], [('Jean', 'person')], [], [('Bob', 'person')], [], [('mamá', 'person')], [('金田不動産', 'person')], [], [('dueña', 'person'), ('de', 'person'), ('la', 'person'), ('inmobiliaria', 'person')], [('Justine', 'person'), ('Lemoine', 'person')], [], [('Bobby', 'person')], [('Grégoire', 'person')], [], [], [], [], [], [], [('Léonie', 'person')], [], [], [], [('John', 'person'), ('Smith', 'person'), ('su', 'content'), ('familia', 'content')], [], [('Pedro', 'person')], [('Antoine', 'person')], [], [('papá', 'person'), ('ven', 'content'), ('ya', 'content'), ('a', 'content'), ('casa', 'content')], [('Pedro', 'person')], [('Anne', 'person')], [('Bob', 'person')], [('John', 'person'), ('project', 'content')], [], [], [('Mélanie', 'person'), ('anniversaire', 'content'), ('de', 'content'), ('Pierre', 'content')], [('tante', 'person'), ('Léa', 'person')], [], [('meeting', 'content'), ('at', 'content'), ('the', 'content'), ('café', 'content')], [('Émilie', 'person')], [], [], [], [('my', 'person'), ('office', 'person'), ('Mr', 'content'), ('.', 'content'), ("Anderson's", 'content'), ('opinion', 'content')], [], [], [('Bina', 'person')], [('Olivier', 'person'), ('Durand', 'person')], [('María', 'person')], [], [('Simon', 'person')], [], [('Susie', 'person')], [], [], [], [], [], [], [], [('Andres', 'person')], [('Chris', 'person')], [('Harry', 'person')], [], [], [('Darrick', 'person')], [], [('Christian', 'person')] ...

# %%
print(predicted_entities)
# Out:
# [[], [], [('María', 'person')], [('Bob', 'person')], [], [], [('Mama', 'person')], [('get', 'person'), ('kid', 'person'), ('son', 'content'), ('aus', 'content'), ('Kindergarten', 'content')], [], [], [('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('Love', 'content'), ('and', 'content'), ('other', 'content'), ('drugs', 'content')], [('François', 'person')], [], [], [('reunión', 'content'), ('12:30', 'content')], [('Hélène', 'person'), ('Gérard', 'person')], [], [], [('mamá', 'person')], [('Roberto', 'person')], [('太郎', 'person')], [], [('Anna', 'person')], [], [('buy', 'content'), ('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('私', 'person')], [], [], [('buy', 'content'), ('chocolate', 'content')], [], [], [], [], [], [], [('book', 'content'), ('the', 'content'), ('flight', 'content')], [], [], [], [], [('Bunny', 'person')], [], [], [], [('my', 'person'), ('Vater', 'person')], [('papá', 'person')], [('夜9時', 'person')], [], [('kaufen', 'content')], [], [], [], [('fiesta', 'content'), ('esta', 'content'), ('noche', 'content')], [], [], [], [], [('love', 'content'), ('you', 'content')], [], [('María', 'person')], [('Dad', 'person')], [], [('Papa', 'person')], [], [], [], [('buy', 'content'), ('milk', 'content'), ('and', 'content'), ('eggs', 'content')], [], [('Bob', 'person')], [], [('mamá', 'person')], [], [('Ambitionen', 'person')], [('barbecue', 'content'), ('at', 'content'), ('Marie', 'content')], [], [('Hildegard', 'person')], [], [('Julien', 'person'), ('Leclerc', 'person')], [], [], [('Nathalie', 'person'), ('Bonnet', 'person')], [], [('Olivier', 'person')], [], [('Textnachricht', 'person'), ('Bob', 'person')], [], [('Bob', 'person')], [('Amita', 'person')], [], [], [], [], [('Juan', 'person')], [('Pierre', 'person')], [], [('Mike', 'person')], [], [], [], [('Ana', 'person')], [], [], [('ケント', 'person')], [], [('please', 'content'), ('rsvp', 'content'), ('below', 'content')], [('with', 'content'), ('care', 'content')], [('Tom', 'person')], [('Ángela', 'person')], [('Jean', 'person')], [], [('Bob', 'person')], [], [('mamá', 'person')], [], [], [], [('Justine', 'person'), ('Lemoine', 'person')], [], [('Bobby', 'person')], [('Grégoire', 'person')], [], [], [], [], [], [('yoga', 'content'), ('classes', 'content')], [('Léonie', 'person')], [], [], [], [('John', 'person'), ('Smith', 'person')], [], [('Pedro', 'person')], [('Antoine', 'person')], [], [('papá', 'person')], [('Pedro', 'person')], [('Anne', 'person')], [('Bob', 'person')], [('John', 'person'), ('the', 'content'), ('project', 'content')], [], [], [('Mélanie', 'person'), ('Pierre', 'content')], [('tante', 'person'), ('Léa', 'person')], [], [], [('Émilie', 'person')], [], [], [], [('my', 'person'), ('office', 'person'), ('Anderson', 'person')], [], [('今週', 'person')], [('Bina', 'person')], [], [('María', 'person')], [], [('Simon', 'person')], [], [('Susie', 'person')], [], [], [], [], [], [], [], [('Andres', 'person')], [('Chris', 'person')], [('Harry', 'person')], [], [], [('Darrick', 'person')], [], [('Christian', 'person')], [], [], [('please', 'content'), ('rsvp', 'content'), ('below', 'content')], [], [('Joseph', 'person')], [], [], [], [(',', 'person'), ('dad', 'person')], [], [], [('Matt', 'person')], [('John', 'person')], [], [], [('John', 'person')], [], [], [('RSVP', 'content'), ('below', 'content')], [], [('Stevie', 'person')], [('my', 'person'), ('mom', 'person')], [], [('Joey', 'person')], [], [], [], [], [('Janice', 'person')], [], [('Rob', 'person')], [('Tom', 'person')], [('Samuel', 'person')], [('Katie', 'person')], [], [], [('Mal', 'person')], [('board', 'person')], [], [], [], [], [('Sharon', 'person'), ('Tess', 'person')], [('Don', 'person'), ('no', 'person'), ('Cheryl', 'person')], [('Clayton', 'person')], [('Kenny', 'person')], [], [('Thomas', 'person'), ('Jake', 'person')], [('my', 'person'), ('office', 'person')], [('Julie', 'person')], [], [('my', 'person'), ('boss', 'person')], [('Robb', 'person')], [ ...

# %% [markdown]
# -----

# %% [markdown]
# 1.Développer un classifier requête -> tâche

# %%
def send_message(receiver, content, **kwargs):
    return f"Sent to \"{receiver}\" the message: \"{content}\""


def ask_RAG(question):
    return f"Asked to RAG: \"{question}\"\nThe RAG replied: \"I don't know\""

# %%
send_message(**api_call_json)
# Out:
# 'Sent to "the python teacher" the message: "when is next class"'
